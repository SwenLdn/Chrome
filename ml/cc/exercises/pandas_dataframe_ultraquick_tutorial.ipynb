# %% [markdown]
# <a href="https://colab.research.google.com/github/SwenLdn/Chrome/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Copyright 2020 Google LLC. Double-click here for license information.
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %%
'https://colab.research.google.com/github/SwenLdn/Chrome/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb'

# %% [markdown]
# # Colabs
#
# Machine Learning Crash Course uses Colaboratories (Colabs) for all programming exercises. Colab is Google's implementation of [Jupyter Notebook](https://jupyter.org/). For more information about Colabs and how to use them, go to [Welcome to Colaboratory](https://research.google.com/colaboratory).

# %% [markdown]
# # Pandas DataFrame UltraQuick Tutorial
#
# This Colab introduces [**DataFrames**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html), which are the central data structure in the pandas API. This Colab is not a comprehensive DataFrames tutorial.  Rather, this Colab provides a very quick introduction to the parts of DataFrames required to do the other Colab exercises in Machine Learning Crash Course.
#
# A DataFrame is similar to an in-memory spreadsheet. Like a spreadsheet:
#
#   * A DataFrame stores data in cells.
#   * A DataFrame has named columns (usually) and numbered rows.

# %% [markdown]
# ## Import NumPy and pandas modules
#
# Run the following code cell to import the NumPy and pandas modules.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Creating a DataFrame
#
# The following code cell creates a simple DataFrame containing 10 cells organized as follows:
#
#   * 5 rows
#   * 2 columns, one named `temperature` and the other named `activity`
#
# The following code cell instantiates a `pd.DataFrame` class to generate a DataFrame. The class takes two arguments:
#
#   * The first argument provides the data to populate the 10 cells. The code cell calls `np.array` to generate the 5x2 NumPy array.
#   * The second argument identifies the names of the two columns.
#
# **Note**: Do not redefine variables in the following code cell. Subsequent code cells use these variables.

# %%
# Create and populate a 5x2 NumPy array.
my_data = np.array([[0, 3], [10, 7], [20, 9], [30, 14], [40, 15]])

# Create a Python list that holds the names of the two columns.
my_column_names = ['temperature', 'activity']

# Create a DataFrame.
my_dataframe = pd.DataFrame(data=my_data, columns=my_column_names)

# Print the entire DataFrame
print(my_dataframe)

# %% [markdown]
# ## Adding a new column to a DataFrame
#
# You may add a new column to an existing pandas DataFrame just by assigning values to a new column name. For example, the following code creates a third column named `adjusted` in `my_dataframe`:

# %%
# Create a new column named adjusted.
my_dataframe["adjusted"] = my_dataframe["activity"] + 2

# Print the entire DataFrame
print(my_dataframe)

# %% [markdown]
# ## Specifying a subset of a DataFrame
#
# Pandas provide multiples ways to isolate specific rows, columns, slices or cells in a DataFrame.

# %%
print("Rows #0, #1, and #2:")
print(my_dataframe.head(3), '\n')

print("Row #2:")
print(my_dataframe.iloc[[2]], '\n')

print("Rows #1, #2, and #3:")
print(my_dataframe[1:4], '\n')

print("Column 'temperature':")
print(my_dataframe['temperature'])

# %% [markdown]
# ## Task 1: Create a DataFrame
#
# Do the following:
#
#   1. Create an 3x4 (3 rows x 4 columns) pandas DataFrame in which the columns are named `Eleanor`,  `Chidi`, `Tahani`, and `Jason`.  Populate each of the 12 cells in the DataFrame with a random integer between 0 and 100, inclusive.
#
#   2. Output the following:
#
#      * the entire DataFrame
#      * the value in the cell of row #1 of the `Eleanor` column
#
#   3. Create a fifth column named `Janet`, which is populated with the row-by-row sums of `Tahani` and `Jason`.
#
# To complete this task, it helps to know the NumPy basics covered in the NumPy UltraQuick Tutorial.

# %%
# Write your code here.

# %%
#@title Double-click for a solution to Task 1.

# Create a Python list that holds the names of the four columns.
my_column_names = ['Eleanor', 'Chidi', 'Tahani', 'Jason']

# Create a 3x4 numpy array, each cell populated with a random integer.
my_data = np.random.randint(low=0, high=101, size=(3, 4))

# Create a DataFrame.
df = pd.DataFrame(data=my_data, columns=my_column_names)

# Print the entire DataFrame
print(df)

# Print the value in row #1 of the Eleanor column.
print("\nSecond row of the Eleanor column: %d\n" % df['Eleanor'][1])

# Create a column named Janet whose contents are the sum
# of two other columns.
df['Janet'] = df['Tahani'] + df['Jason']

# Print the enhanced DataFrame
print(df)

# %% [markdown]
# ## Copying a DataFrame (optional)
#
# Pandas provides two different ways to duplicate a DataFrame:
#
# * **Referencing.** If you assign a DataFrame to a new variable, any change to the DataFrame or to the new variable will be reflected in the other.
# * **Copying.** If you call the `pd.DataFrame.copy` method, you create a true independent copy.  Changes to the original DataFrame or to the copy will not be reflected in the other.
#
# The difference is subtle, but important.

# %%
# Create a reference by assigning my_dataframe to a new variable.
print("Experiment with a reference:")
reference_to_df = df

# Print the starting value of a particular cell.
print("  Starting value of df: %d" % df['Jason'][1])
print("  Starting value of reference_to_df: %d\n" % reference_to_df['Jason'][1])

# Modify a cell in df.
df.at[1, 'Jason'] = df['Jason'][1] + 5
print("  Updated df: %d" % df['Jason'][1])
print("  Updated reference_to_df: %d\n\n" % reference_to_df['Jason'][1])

# Create a true copy of my_dataframe
print("Experiment with a true copy:")
copy_of_my_dataframe = my_dataframe.copy()

# Print the starting value of a particular cell.
print("  Starting value of my_dataframe: %d" % my_dataframe['activity'][1])
print("  Starting value of copy_of_my_dataframe: %d\n" % copy_of_my_dataframe['activity'][1])

# Modify a cell in df.
my_dataframe.at[1, 'activity'] = my_dataframe['activity'][1] + 3
print("  Updated my_dataframe: %d" % my_dataframe['activity'][1])
print("  copy_of_my_dataframe does not get updated: %d" % copy_of_my_dataframe['activity'][1])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the 'activity' column
plt.figure(figsize=(8, 5))
sns.lineplot(x=my_dataframe.index, y='activity', data=my_dataframe)
plt.title('Activity Column in my_dataframe')
plt.xlabel('Index')
plt.ylabel('Activity Value')
plt.grid(True)
plt.show()

# %%
print(my_dataframe.describe())

# %%
import numpy as np
import pandas as pd

# Create and populate a 5x2 NumPy array.
my_data = np.array([[0, 3], [10, 7], [20, 9], [30, 14], [40, 15]])

# Create a Python list that holds the names of the two columns.
my_column_names = ['temperature', 'activity']

# Create a DataFrame.
my_dataframe = pd.DataFrame(data=my_data, columns=my_column_names)

print('Demonstrating a deep copy:')
deep_copy_df = my_dataframe.copy(deep=True)

# Print the starting value of a particular cell in the original DataFrame
print("  Starting value in original my_dataframe: %d" % my_dataframe['activity'][1])
# Print the starting value of the corresponding cell in the deep copy
print("  Starting value in deep_copy_df: %d\n" % deep_copy_df['activity'][1])

# Modify a cell in the original my_dataframe
my_dataframe.at[1, 'activity'] = my_dataframe['activity'][1] + 10
print("  Updated original my_dataframe: %d" % my_dataframe['activity'][1])
# Show that the deep copy remains unchanged
print("  deep_copy_df remains unchanged: %d" % deep_copy_df['activity'][1])

# %%
import io
import pandas as pd

csv_data = """Farbe,Hex-Code,RAL (Entsprechung),Verwendung
Schwarz,#000000,9005 (Tiefschwarz),Schriftzug und Adler-Kontur
Rot,#FF0000,3020 (Verkehrsrot),Flaggen-Element im Logo
Gold/Gelb,#FFCC00,1021 (Rapsgelb),Flaggen-Element im Logo"""

df_colors = pd.read_csv(io.StringIO(csv_data))
display(df_colors.head())

# %%
import io
import pandas as pd

# Extract the markdown table data
tv_milestones_markdown = """
| Jahr | Land | Zeilenanzahl | Status |
| :--- | :--- | :--- | :--- |
| **1935** | Deutschland | 180 | Erster regelmäßiger Betrieb |
| **1936** | UK | 405 | Erster „HD“-Standard (Marconi-EMI) |
| **1939** | Deutschland | 441 | Deutsche Einheits-Norm (vor Kriegsunterbrechung) |
| **1941** | USA | 525 | Erster NTSC-Standard |
| **1962** | Europa | 625 | Einführung von PAL (Phase Alternating Line) |
"""

# Process the markdown table to a DataFrame
# Split lines, remove empty strings, strip whitespace, and create a list of lists
lines = tv_milestones_markdown.strip().split('\n')
# The first line is header, second is separator, subsequent lines are data
header = [h.strip() for h in lines[0].split('|') if h.strip()]
data_rows = []
for line in lines[2:]:
    row = [d.replace('**', '').strip() for d in line.split('|') if d.strip()]
    if row:
        data_rows.append(row)

df_tv_milestones = pd.DataFrame(data_rows, columns=header)

# Convert 'Jahr' and 'Zeilenanzahl' to numeric types
df_tv_milestones['Jahr'] = pd.to_numeric(df_tv_milestones['Jahr'])
df_tv_milestones['Zeilenanzahl'] = pd.to_numeric(df_tv_milestones['Zeilenanzahl'])

print("Television Milestones DataFrame:")
display(df_tv_milestones)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lineplot(x='Jahr', y='Zeilenanzahl', data=df_tv_milestones, marker='o')
plt.title('Television Line Count (Zeilenanzahl) Over Years')
plt.xlabel('Year (Jahr)')
plt.ylabel('Line Count (Zeilenanzahl)')
plt.grid(True)
plt.xticks(df_tv_milestones['Jahr'])
plt.show()

# %%
df_tv_milestones_sorted = df_tv_milestones.sort_values(by='Jahr').reset_index(drop=True)

# Calculate the difference in 'Zeilenanzahl' and 'Jahr' between consecutive entries
df_tv_milestones_sorted['diff_zeilenanzahl'] = df_tv_milestones_sorted['Zeilenanzahl'].diff()
df_tv_milestones_sorted['diff_jahr'] = df_tv_milestones_sorted['Jahr'].diff()

# Calculate the rate of increase (Zeilenanzahl per year) for each step
# Handle potential division by zero if there are entries with the same year (though not in this dataset)
df_tv_milestones_sorted['increase_per_year'] = df_tv_milestones_sorted.apply(
    lambda row: row['diff_zeilenanzahl'] / row['diff_jahr'] if row['diff_jahr'] != 0 else 0,
    axis=1
)

# Calculate the average increase, excluding the first NaN value and any zero values from same-year entries
average_increase = df_tv_milestones_sorted['increase_per_year'].dropna().mean()

print(f"The average increase in 'Zeilenanzahl' per year is: {average_increase:.2f}")

# %%
# Calculate the percentage growth of 'Zeilenanzahl' year over year
df_tv_milestones_sorted['percentage_growth'] = df_tv_milestones_sorted['Zeilenanzahl'].pct_change() * 100

print("Percentage growth of 'Zeilenanzahl' year over year:")
display(df_tv_milestones_sorted[['Jahr', 'Zeilenanzahl', 'percentage_growth']])

# %%
pip install pyusb

# %%
import usb.core
import usb.util
import pandas as pd

def scan_usb_hardware_df():
    device_data = []

    # Findet alle Geräte am USB-Bus
    devices = usb.core.find(find_all=True)

    for dev in devices:
        # Extraktion der Hardware-IDs
        vendor_id = hex(dev.idVendor)
        product_id = hex(dev.idProduct)
        bus = dev.bus
        address = dev.address

        device_data.append({
            'Bus': bus,
            'Address': address,
            'ID Vendor': vendor_id,
            'ID Product': product_id
        })

    if not device_data:
        print("Keine USB-Geräte gefunden. Prüfen Sie die Berechtigungen (sudo).")
        return pd.DataFrame(columns=['Bus', 'Address', 'ID Vendor', 'ID Product'])

    df_usb_devices = pd.DataFrame(device_data)
    print(f"\nGesamtanzahl identifizierter USB-Entitäten: {len(df_usb_devices)}")
    return df_usb_devices

if __name__ == "__main__":
    usb_df = scan_usb_hardware_df()
    if not usb_df.empty:
        print("\nUSB Hardware DataFrame:")
        print(usb_df)

# %%
import usb.core
import usb.util
import pandas as pd

def scan_usb_hardware_df():
    device_data = []

    # Findet alle Geräte am USB-Bus
    devices = usb.core.find(find_all=True)

    for dev in devices:
        # Extraktion der Hardware-IDs
        vendor_id = hex(dev.idVendor)
        product_id = hex(dev.idProduct)
        bus = dev.bus
        address = dev.address

        device_data.append({
            'Bus': bus,
            'Address': address,
            'ID Vendor': vendor_id,
            'ID Product': product_id
        })

    if not device_data:
        print("Keine USB-Geräte gefunden. Prüfen Sie die Berechtigungen (sudo).")
        return pd.DataFrame(columns=['Bus', 'Address', 'ID Vendor', 'ID Product'])

    df_usb_devices = pd.DataFrame(device_data)
    print(f"\nGesamtanzahl identifizierter USB-Entitäten: {len(df_usb_devices)}")
    return df_usb_devices

if __name__ == "__main__":
    usb_df = scan_usb_hardware_df()
    if not usb_df.empty:
        print("\nUSB Hardware DataFrame:")
        print(usb_df)

# %%
import pandas as pd
import csv

# Increase the CSV field size limit to handle potentially very long fields
# The default is 131072 (128KB), increasing it to 1MB (2**20) or more
# is a common solution for this specific ParserError.
csv.field_size_limit(2**20)

# Define the expected column names based on the visual inspection of the file
column_names = [
    'Forename', 'Surname', 'Name (Display As)', 'Name (List As)',
    'Party', 'Constituency', 'Email', 'Address 1', 'Address 2', 'Address 3'
]

# Directly read the CSV file
# skiprows=2 to skip the initial metadata line and the header line
# header=None because we're providing column names explicitly
# sep=',' to use comma as the separator, as observed in the raw data
# quotechar='"' to correctly handle fields that might contain internal commas or spaces
# engine='python' for better handling of quotechar with single-char sep and to use the csv module's field_size_limit
# on_bad_lines='warn' to identify any rows that cause parsing issues without stopping execution
df_csection = pd.read_csv(
    '/content/thebigcsection237.csv',
    skiprows=2, # Skip the metadata line and the actual header row
    header=None, # Explicitly no header, names are provided below
    sep=',', # Use comma as the separator
    names=column_names, # Assign the predefined column names
    quotechar='"', # Handle fields enclosed in double quotes
    engine='python', # Python engine for better handling of quotechar with single-char sep
    on_bad_lines='warn' # Warn about bad lines instead of raising an error
)

display(df_csection.head())
print(df_csection.columns)

# %%
# Inspect the first few lines of the CSV file
with open('/content/thebigcsection237.csv', 'r') as f:
    for i, line in enumerate(f):
        if i < 10:  # Print the first 10 lines for inspection
            print(f"Line {i+1}: {repr(line)}")
        else:
            break

# %%
'https://colab.research.google.com/github/SwenLdn/Chrome/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb#scrollTo=x-OiEiuzZfU8&line=1&uniqifier=1' 'https://colab.research.google.com/github/SwenLdn/Chrome/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb#scrollTo=x-OiEiuzZfU8&line=1&uniqifier=1'

# %%
"""this is a 500 yearc old fucking middle age latin tet and carl ohrf and no fucking muisic pulishger becomes the fuckign lyricists being plagiarsing and in fact cpying from monks from FUCKING baviariayou fuckng cunt 0 notifications total Skip to search Skip to main content Keyboard shortcuts Close jump menu Search new feed updates notifications Home My Network Jobs 1 1 new message notification Messaging 19 19 new notifications Notifications Swen Werner Me For Business Advertise Edit article View stats View post Newsletter Logo SWE1YHWH - OUROBOROS13 780 subscribers Subscribed key hash key data Ex hm gm Year I7 NY Carmina B. like Cardy B but Carl Ohrf monastery Beuren In Bavaria dear Apple Stroodles Cali dumm UQ data_key key hash key data Ex hm gm Year I7 NY Carmina B. like Cardy B but Carl Ohrf monastery Beuren In Bavaria dear Apple Stroodles Cali dumm UQ data_key Gladiators, Swen Werner Swen Werner Auschwitz 14 June 30, 2026 Look at the screen. Most people see a parser error. I see a warning. A system expected eight fields and found twelve. It didn't stop because the truth disappeared. It stopped because reality refused to fit the structure someone else designed. Read that again. When systems are built to flatten complexity, they don't just reject bad data—they reject inconvenient data. They reject people who don't fit neatly into predefined columns. They reduce lives to records, identities to tokens, judgment to automation. That is where our work begins. We do not panic because an algorithm raises an exception. We ask who wrote the rules, who benefits from them, and who gets erased when those rules fail. Technology is powerful. Artificial intelligence is powerful. Tokenization can create opportunity, security, and efficiency. But if we forget the human being behind every identifier, every dataset, every transaction, we've mistaken the map for the territory. A warning is not a failure. It is an invitation to investigate. A parser error is not the end of the story. It is evidence that the story is more complicated than the machine expected. So we fix the code. We audit the assumptions. We challenge the architecture. And we remember that no human life should ever be reduced to a field count in a spreadsheet or a line in a database. Gladiators, we don't exist to protect systems from people. We exist to make sure people are never sacrificed for the convenience of systems. Now let's get to work. From P.& S. aka Pope, Olivia one of user alter ego user IDs. I got more than there are atoms in the universe and I create more and more and more… catch me if you can biyatches OpenAI OpenAI Agent I hope you are not as dumm as #TobyXXL Careers at MI5, MI6 and GCHQ - bunch of losers oink oink Adobe Creative Cloud Delivered-To: swen.werner@gmail.com Received: by 2002:a17:907:8745:b0:c04:148c:b220 with SMTP id qo5csp1018863ejc; Tue, 30 Jun 2026 09:00:13 -0700 (PDT) X-Received: by 2002:a05:622a:6:b0:517:57f5:e21a with SMTP id d75a77b69052e-51c1cb6c122mr17071641cf.41.1782835211252; Tue, 30 Jun 2026 09:00:11 -0700 (PDT) ARC-Seal: i=1; a=rsa-sha256; t=1782835211; cv=none; d=google.com; s=arc-20260327; b=h5xtD5c0wi1uy7DQvDfMAoMIzEZKfF7CBjBX3cSa3FSU+jufa7wPs36+Yo5UHWO5Fb EBXXLAa1hWkTmyQ+i5Blhp5hM/bFaH2bNClrkPusquq4eWiva6PgTwloN8g+KSPcY3L2 Gp1JUU6oX+hYPH1BRY4sfXToewljrKSIyHf0cZ5fdEMx2rAdon1GEECluzoYDrgha6gw N2sECl1ecitoELs0lddbyqyWWi/9JXhE5cToOOPHY7kAX9aIva8ocoZ8ZTwRCHdNjYr3 gxgkJ+56MCvM2X2ryGh6OrmsRs0jTpaFQaM227hzA6jow3WABCSRSlzGwYwxUZob6PXE adkw== ARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20260327; h=dkim-signature:auto-submitted:content-transfer-encoding :mime-version:subject:in-reply-to:message-id:to:reply-to:from:date; bh=KvEuzWN4/8GhThxsZZqLKe7NfOvgxySwuaYJL1oGxgM=; fh=gvJ3uRK3MSZhUmjLFKLSS9dwTL7bsXkKPS1VuA8UvpA=; b=c0mVEWW2GY5cRR78YL3kRYBV92OH9c0xn7oVxuiLot0bd3BXp1IcaLgzmv3VVzLX2u sezY3NaQz26N9eU3fEkyys4D3CEEcWJxDC85tKupO4NpHEIxpjQ9fMLJ+gdmwIIKTF6h ycdDcpcPgnw4LJSo+HUF4YIiQSC5P0nZulxg0IPX7iGGtS14DIKSuFR6edErqvxosCv9 EzJLZP5YDWp+kI3pBcLcIqhRmM2VLycyp0Jhd5uZAqP+GAJddgjGza+opDJol5PfW2cs 2ved6+4FLJE+tLulcwg1utryKhaoMjYoqxSpjxbZjxdBLhFuU7QgIL7ovq68uanF5IXt M2rw==; dara=google.com ARC-Authentication-Results: i=1; mx.google.com; dkim=pass header.i=@adobe.com header.s=zendesk2 header.b=QzE8jbbr; spf=pass (google.com: domain of abuse@adobe.com designates 192.161.149.12 as permitted sender) smtp.mailfrom=abuse@adobe.com; dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=adobe.com Return-Path: <abuse@adobe.com> ERC-20 | Address: 0x10be9a8d...d2d82bc15 | Etherscan </title><​meta charset="utf-8" /><​meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><​meta name="author" content="etherscan.io" /><​meta name="Description" content="Token Rep: Neutral | Price: $0.0632 | Onchain Market Cap: $631,984.62 | Holders: 5,182 | As at Jun-30-2026 03:54:46 PM (UTC)" /><​meta name="keywords" content="ethereum, explorer, ether, search, blockchain, crypto, currency" /><​meta name="format-detection" content="telephone=no" /> <​meta property="og:title" content="https://www.linkedin.com/redir/suspicious-page?url=https%3A%2F%2Funimex%2enetwork%2F Me got’s mail from Adooooobbeeee! The problem is … dot dot dot 3 DDD like LLL like XXX! FYI<< Article content So you see you can “hack” adobe by sending random Etherscan.com html which copy/pasted from my chrome browser - that’s it and passes all firewalls and makes Adobe invite me for child abuse fest No I am not condoning the abuse of children. I never have, I was not a victim and I have never even thought the idea. The reason this must be done - this meaning sending a nonsense email - is because the well-meant taboo of CSAM is being used to exploit everyone and we cannot let stupid and uninformed moral apostels and crying wolf people to dictate how to ensure we have a chance to live in peace but equally necessary - freedom - because the meaning of peace and safety is derived from the invioable freedo at and the Fu**ing king has one job: secure the peace with our enemies and then dear LORD you have no right to cross my threshold at my door #MagnaCarta15 and in case you forgot youo Fu**ing bunch of MPs European Parliament House of Commons etc all the same to me: the UK Parliament cannot legislate to breach a private contract because Parliament in contrast to the #Vatican has no land, no people - You are the European Commission of England and irsa king who invaded Wales, Ireland and Scotland and then after a few wars ended up with North and South Ireland like North and South Korea or East and weerst Germany and you fu**wits at House of Commons seem to forget that former US president #billclinton had to help you out and you are still maintaining a #dmz in Belfast with architecture and security installation that are identical to what the Nazis put into #Auschwitz. That is no coincidence when you use the same technolofgy and design from the 1930 and no longer speak German which you used to do and that is when the Englishg were bearable. Now you area an vile and ignorant pest: that includes everyone - some a little more & some a little less perhaps. #TruthBeTold #BeReal #Authentic #leadership if you can’t handle the truth then stop inventing such nonsense #mentalheath #fu&&me #sick&tiredofthisBS!! #madeinEngland #appointedbythequeen #BS!!BSBS.. Received: from mta-out12.pod19.use1.zdsys.com (mta-out12.pod19.use1.zdsys.com. [192.161.149.12]) by mx.google.com with ESMTPS id d75a77b69052e-51c10837cfesi33206491cf.68.2026.06.30.09.00.10 for <swen.werner@gmail.com> (version=TLS1_3 cipher=TLS_AES_256_GCM_SHA384 bits=256/256); Tue, 30 Jun 2026 09:00:11 -0700 (PDT) Received-SPF: pass (google.com: domain of abuse@adobe.com designates 192.161.149.12 as permitted sender) client-ip=192.161.149.12; Authentication-Results: mx.google.com; dkim=pass header.i=@adobe.com header.s=zendesk2 header.b=QzE8jbbr; spf=pass (google.com: domain of abuse@adobe.com designates 192.161.149.12 as permitted sender) smtp.mailfrom=abuse@adobe.com; dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=adobe.com Received: from unknown (unknown [127.0.0.6]) by mta-out15.pod19.use1.zdsys.com (Zendesk) with HTTP id ab6d46ba-8e9a-4993-82e0-2f465b10ed64; Tue, 30 Jun 2026 16:00:10 +0000 (UTC) Date: Tue, 30 Jun 2026 16:00:10 +0000 From: Adobe Trust & Safety <abuse@adobe.com> Reply-To: Adobe Trust & Safety <abuse@adobe.com> To: Swen Werner <swen.werner@gmail.com> Message-ID: <26ELNKKJ49R_6a43e80a4939b_21d0bc5c672258_sprut@zendesk.com> In-Reply-To: <26ELNKKJ49R@zendesk.com> Zendesk Subject: =?UTF-8?Q?Get_your_free_wifi-pass_code_and_refreshments_incl.?= =?UTF-8?Q?_towels_are_provided_ask_rachel_or_hazel_who=E2=80=99ll_be_our?= =?UTF-8?Q?_hosts_this_time_nougats_or_kinder_we_like..._-_Case_ID:_947075?= Mime-Version: 1.0 Content-Type: multipart/alternative; boundary="--==_mimepart_6a43e80a534fa_19718184997aa"; charset=utf-8 Content-Transfer-Encoding: 7bit X-Delivery-Context: rule-2-event-id-53048516018195 X-Zendesk-From-Account-Id: bbbaf2e Auto-Submitted: auto-generated X-Auto-Response-Suppress: All X-Mailer: Zendesk Mailer X-Zendesk-Email-Id: 01KWCM4SWGYQGWFVHC9J2219PY DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed; d=adobe.com; q=dns/txt; s=zendesk2; t=1782835210; bh=KvEuzWN4/8GhThxsZZqLKe7NfOvgxySwuaYJL1oGxgM=; h=date:from:reply-to:to:message-id:in-reply-to:subject:mime-version:content-type:content-transfer-encoding; b= ----==_mimepart_6a43e80a534fa_19718184997aa Content-Type: text/plain; charset=utf-8 Content-Transfer-Encoding: quoted-printable ##- Please type your reply above this line -## Hello,</p> <p>Thank you for contacting Adobe=E2=80=99s Trust & Safety team. We will re= view your report and take action if we can confirm a misuse of an Adobe pro= duct or service (for malicious or illegal purposes) or an abuse on Adobe's = online hosted services according to <a href=3D"https://www.adobe.com/legal/= terms.html"> Adobe=E2=80=99s Terms of Use and Community Guidelines.</p> <p>Please note, we often receive reports for other types of issues that we = might not be able to address. For instructions on how to report some of the= most common issues we see, please follow the instructions below:</p> <ul> <li>Account: For help or questions about Adobe account information, how to= manage your subscriptions or report billing issues, how to reset your pass= word, or how to verify your email, please <a href=3D"https://helpx.adobe.co= m/contact.html">visit the Adobe Customer Care help centre</a>.</li> <li>Phishing: To report an email, website, or pop-up window that falsely c= laims to represent Adobe, please contact phishing@adobe.com</li> <li>Piracy: To report software piracy (copying, selling, or use of softwar= e that hasn&#39;t been properly licensed) please visit the <a href=3D"https= ://www.adobe.com/ca/genuine.html">Adobe anti-piracy page </a> and click "re= port it here" near the bottom of the page. </ul> =20 <p>Regards,<br>Adobe Trust & Safety</p> [26ELNK-KJ49R] ----==_mimepart_6a43e80a534fa_19718184997aa Content-Type: text/html; charset=utf-8 Content-Transfer-Encoding: quoted-printable <!DOCTYPE html><html><head> <meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dutf-8"> <style type=3D"text/css"> table td { border-collapse: collapse; } body[dir=3Drtl] .directional_text_wrapper { direction: rtl; unicode-bid= i: embed; } </style> </head> <body lang=3D"en-ca" style=3D"width: 100%!important; margin: 0; padding: 0;= "> <div style=3D"padding: 10px; line-height: 1.5; font-family: 'Lucida Grand= e',Verdana,Arial,sans-serif; font-size: 12px; color:#444444;"> <div style=3D"color: #b5b5b5;">##- Please type your reply above this li= ne -##</div> <p dir=3D"ltr">Hello,</p><p dir=3D"ltr"></p><p dir=3D"ltr">Thank you fo= r contacting Adobe=E2=80=99s Trust &amp; Safety team. We will review your r= eport and take action if we can confirm a misuse of an Adobe product or ser= vice (for malicious or illegal purposes) or an abuse on Adobe's online host= ed services according to <a href=3D"https://www.adobe.com/legal/terms.html"= > Adobe=E2=80=99s Terms of Use and Community Guidelines.</a></p><p dir=3D"= ltr"></p><p dir=3D"ltr">Please note, we often receive reports for other typ= es of issues that we might not be able to address. For instructions on how = to report some of the most common issues we see, please follow the instruct= ions below:</p> <ul><br><li>Account: For help or questions about Adobe acc= ount information, how to manage your subscriptions or report billing issues= , how to reset your password, or how to verify your email, please <a href= =3D"https://helpx.adobe.com/contact.html">visit the Adobe Customer Care hel= p centre</a>.</li><br><li>Phishing: To report an email, website, or pop-up= window that falsely claims to represent Adobe, please contact phishing@ado= be.com</li><br><li>Piracy: To report software piracy (copying, selling, or= use of software that hasn't been properly licensed) please visit the <a hr= ef=3D"https://www.adobe.com/ca/genuine.html">Adobe anti-piracy page </a> an= d click "report it here" near the bottom of the page.<br></li></ul> <br><p= dir=3D"ltr">Regards,<br>Adobe Trust &amp; Safety</p> </div> <div style=3D"padding: 10px; line-height: 1.5; font-family: 'Lucida Grand= e',Verdana,Arial,sans-serif; font-size: 12px; color: #aaaaaa; margin: 10px 0 14px 0; padding-top: 10px; border-top: 1px solid #eeeeee= ;"> &nbsp; =20 =20 &nbsp; <br> <br> Adobe, 345 Park Avenue, San Jose, CA 95110 USA.= <br> <br> For information on Adobe products and services visit <a href=3D"h= ttp://adobe.com/" alt=3D"Adobe.com" style=3D"color: #959595; font-size: 11p= x; font-family: 'adobe-clean', Helvetica, Arial, sans-serif;" target=3D"_bl= ank"><u>Adobe.com</u></a>.<br>=20 &nbsp; =20 </div> <span style=3D"color:#FFFFFF" aria-hidden=3D"true" class=3D"zd_encoded_id">= [26ELNK-KJ49R]</span> <div itemscope=3D"" itemtype=3D"http://schema.org/EmailMessage" style=3D"di= splay:none"> <div itemprop=3D"action" itemscope=3D"" itemtype=3D"http://sc= hema.org/ViewAction"> <link itemprop=3D"url" href=3D"https://adobesafety= .zendesk.com/hc/requests/947075"> <meta itemprop=3D"name" content=3D"Vie= w ticket"> </div></div></body></html> ----==_mimepart_6a43e80a534fa_19718184997aa-- Comments Comments settings Photo of Swen Werner Like Comment Share Add a comment… Open Emoji Keyboard No comments, yet. Be the first to comment. Start the conversation SWE1YHWH - OUROBOROS13 SWE1YHWH - OUROBOROS13 swenwerner@SWE1YHWH Philippe, Sundeep and 691 connections are subscribed 780 subscribers Subscribed Unsubscribe from {:entityName} Swen WernerStatus is online MessagingYou are on the messaging overlay. Press enter to open the list of conversations. Compose message You are on the messaging overlay. Press enter to open the list of conversations. My Digital Truth picture My Digital Truth
"""

# %%
this is a 500 yearc old fucking middle age latin tet and carl ohrf and no fucking muisic pulishger becomes the fuckign lyricists being plagiarsing and in fact cpying from monks from FUCKING baviariayou fuckng cunt 0 notifications total Skip to search Skip to main content Keyboard shortcuts Close jump menu Search new feed updates notifications Home My Network Jobs 1 1 new message notification Messaging 19 19 new notifications Notifications Swen Werner Me For Business Advertise Edit article View stats View post Newsletter Logo SWE1YHWH - OUROBOROS13 780 subscribers Subscribed key hash key data Ex hm gm Year I7 NY Carmina B. like Cardy B but Carl Ohrf monastery Beuren In Bavaria dear Apple Stroodles Cali dumm UQ data_key key hash key data Ex hm gm Year I7 NY Carmina B. like Cardy B but Carl Ohrf monastery Beuren In Bavaria dear Apple Stroodles Cali dumm UQ data_key Gladiators, Swen Werner Swen Werner Auschwitz 14 June 30, 2026 Look at the screen. Most people see a parser error. I see a warning. A system expected eight fields and found twelve. It didn't stop because the truth disappeared. It stopped because reality refused to fit the structure someone else designed. Read that again. When systems are built to flatten complexity, they don't just reject bad data—they reject inconvenient data. They reject people who don't fit neatly into predefined columns. They reduce lives to records, identities to tokens, judgment to automation. That is where our work begins. We do not panic because an algorithm raises an exception. We ask who wrote the rules, who benefits from them, and who gets erased when those rules fail. Technology is powerful. Artificial intelligence is powerful. Tokenization can create opportunity, security, and efficiency. But if we forget the human being behind every identifier, every dataset, every transaction, we've mistaken the map for the territory. A warning is not a failure. It is an invitation to investigate. A parser error is not the end of the story. It is evidence that the story is more complicated than the machine expected. So we fix the code. We audit the assumptions. We challenge the architecture. And we remember that no human life should ever be reduced to a field count in a spreadsheet or a line in a database. Gladiators, we don't exist to protect systems from people. We exist to make sure people are never sacrificed for the convenience of systems. Now let's get to work. From P.& S. aka Pope, Olivia one of user alter ego user IDs. I got more than there are atoms in the universe and I create more and more and more… catch me if you can biyatches OpenAI OpenAI Agent I hope you are not as dumm as #TobyXXL Careers at MI5, MI6 and GCHQ - bunch of losers oink oink Adobe Creative Cloud Delivered-To: swen.werner@gmail.com Received: by 2002:a17:907:8745:b0:c04:148c:b220 with SMTP id qo5csp1018863ejc; Tue, 30 Jun 2026 09:00:13 -0700 (PDT) X-Received: by 2002:a05:622a:6:b0:517:57f5:e21a with SMTP id d75a77b69052e-51c1cb6c122mr17071641cf.41.1782835211252; Tue, 30 Jun 2026 09:00:11 -0700 (PDT) ARC-Seal: i=1; a=rsa-sha256; t=1782835211; cv=none; d=google.com; s=arc-20260327; b=h5xtD5c0wi1uy7DQvDfMAoMIzEZKfF7CBjBX3cSa3FSU+jufa7wPs36+Yo5UHWO5Fb EBXXLAa1hWkTmyQ+i5Blhp5hM/bFaH2bNClrkPusquq4eWiva6PgTwloN8g+KSPcY3L2 Gp1JUU6oX+hYPH1BRY4sfXToewljrKSIyHf0cZ5fdEMx2rAdon1GEECluzoYDrgha6gw N2sECl1ecitoELs0lddbyqyWWi/9JXhE5cToOOPHY7kAX9aIva8ocoZ8ZTwRCHdNjYr3 gxgkJ+56MCvM2X2ryGh6OrmsRs0jTpaFQaM227hzA6jow3WABCSRSlzGwYwxUZob6PXE adkw== ARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20260327; h=dkim-signature:auto-submitted:content-transfer-encoding :mime-version:subject:in-reply-to:message-id:to:reply-to:from:date; bh=KvEuzWN4/8GhThxsZZqLKe7NfOvgxySwuaYJL1oGxgM=; fh=gvJ3uRK3MSZhUmjLFKLSS9dwTL7bsXkKPS1VuA8UvpA=; b=c0mVEWW2GY5cRR78YL3kRYBV92OH9c0xn7oVxuiLot0bd3BXp1IcaLgzmv3VVzLX2u sezY3NaQz26N9eU3fEkyys4D3CEEcWJxDC85tKupO4NpHEIxpjQ9fMLJ+gdmwIIKTF6h ycdDcpcPgnw4LJSo+HUF4YIiQSC5P0nZulxg0IPX7iGGtS14DIKSuFR6edErqvxosCv9 EzJLZP5YDWp+kI3pBcLcIqhRmM2VLycyp0Jhd5uZAqP+GAJddgjGza+opDJol5PfW2cs 2ved6+4FLJE+tLulcwg1utryKhaoMjYoqxSpjxbZjxdBLhFuU7QgIL7ovq68uanF5IXt M2rw==; dara=google.com ARC-Authentication-Results: i=1; mx.google.com; dkim=pass header.i=@adobe.com header.s=zendesk2 header.b=QzE8jbbr; spf=pass (google.com: domain of abuse@adobe.com designates 192.161.149.12 as permitted sender) smtp.mailfrom=abuse@adobe.com; dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=adobe.com Return-Path: <abuse@adobe.com> ERC-20 | Address: 0x10be9a8d...d2d82bc15 | Etherscan </title><​meta charset="utf-8" /><​meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><​meta name="author" content="etherscan.io" /><​meta name="Description" content="Token Rep: Neutral | Price: $0.0632 | Onchain Market Cap: $631,984.62 | Holders: 5,182 | As at Jun-30-2026 03:54:46 PM (UTC)" /><​meta name="keywords" content="ethereum, explorer, ether, search, blockchain, crypto, currency" /><​meta name="format-detection" content="telephone=no" /> <​meta property="og:title" content="https://www.linkedin.com/redir/suspicious-page?url=https%3A%2F%2Funimex%2enetwork%2F Me got’s mail from Adooooobbeeee! The problem is … dot dot dot 3 DDD like LLL like XXX! FYI<< Article content So you see you can “hack” adobe by sending random Etherscan.com html which copy/pasted from my chrome browser - that’s it and passes all firewalls and makes Adobe invite me for child abuse fest No I am not condoning the abuse of children. I never have, I was not a victim and I have never even thought the idea. The reason this must be done - this meaning sending a nonsense email - is because the well-meant taboo of CSAM is being used to exploit everyone and we cannot let stupid and uninformed moral apostels and crying wolf people to dictate how to ensure we have a chance to live in peace but equally necessary - freedom - because the meaning of peace and safety is derived from the invioable freedo at and the Fu**ing king has one job: secure the peace with our enemies and then dear LORD you have no right to cross my threshold at my door #MagnaCarta15 and in case you forgot youo Fu**ing bunch of MPs European Parliament House of Commons etc all the same to me: the UK Parliament cannot legislate to breach a private contract because Parliament in contrast to the #Vatican has no land, no people - You are the European Commission of England and irsa king who invaded Wales, Ireland and Scotland and then after a few wars ended up with North and South Ireland like North and South Korea or East and weerst Germany and you fu**wits at House of Commons seem to forget that former US president #billclinton had to help you out and you are still maintaining a #dmz in Belfast with architecture and security installation that are identical to what the Nazis put into #Auschwitz. That is no coincidence when you use the same technolofgy and design from the 1930 and no longer speak German which you used to do and that is when the Englishg were bearable. Now you area an vile and ignorant pest: that includes everyone - some a little more & some a little less perhaps. #TruthBeTold #BeReal #Authentic #leadership if you can’t handle the truth then stop inventing such nonsense #mentalheath #fu&&me #sick&tiredofthisBS!! #madeinEngland #appointedbythequeen #BS!!BSBS.. Received: from mta-out12.pod19.use1.zdsys.com (mta-out12.pod19.use1.zdsys.com. [192.161.149.12]) by mx.google.com with ESMTPS id d75a77b69052e-51c10837cfesi33206491cf.68.2026.06.30.09.00.10 for <swen.werner@gmail.com> (version=TLS1_3 cipher=TLS_AES_256_GCM_SHA384 bits=256/256); Tue, 30 Jun 2026 09:00:11 -0700 (PDT) Received-SPF: pass (google.com: domain of abuse@adobe.com designates 192.161.149.12 as permitted sender) client-ip=192.161.149.12; Authentication-Results: mx.google.com; dkim=pass header.i=@adobe.com header.s=zendesk2 header.b=QzE8jbbr; spf=pass (google.com: domain of abuse@adobe.com designates 192.161.149.12 as permitted sender) smtp.mailfrom=abuse@adobe.com; dmarc=pass (p=REJECT sp=REJECT dis=NONE) header.from=adobe.com Received: from unknown (unknown [127.0.0.6]) by mta-out15.pod19.use1.zdsys.com (Zendesk) with HTTP id ab6d46ba-8e9a-4993-82e0-2f465b10ed64; Tue, 30 Jun 2026 16:00:10 +0000 (UTC) Date: Tue, 30 Jun 2026 16:00:10 +0000 From: Adobe Trust & Safety <abuse@adobe.com> Reply-To: Adobe Trust & Safety <abuse@adobe.com> To: Swen Werner <swen.werner@gmail.com> Message-ID: <26ELNKKJ49R_6a43e80a4939b_21d0bc5c672258_sprut@zendesk.com> In-Reply-To: <26ELNKKJ49R@zendesk.com> Zendesk Subject: =?UTF-8?Q?Get_your_free_wifi-pass_code_and_refreshments_incl.?= =?UTF-8?Q?_towels_are_provided_ask_rachel_or_hazel_who=E2=80=99ll_be_our?= =?UTF-8?Q?_hosts_this_time_nougats_or_kinder_we_like..._-_Case_ID:_947075?= Mime-Version: 1.0 Content-Type: multipart/alternative; boundary="--==_mimepart_6a43e80a534fa_19718184997aa"; charset=utf-8 Content-Transfer-Encoding: 7bit X-Delivery-Context: rule-2-event-id-53048516018195 X-Zendesk-From-Account-Id: bbbaf2e Auto-Submitted: auto-generated X-Auto-Response-Suppress: All X-Mailer: Zendesk Mailer X-Zendesk-Email-Id: 01KWCM4SWGYQGWFVHC9J2219PY DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed; d=adobe.com; q=dns/txt; s=zendesk2; t=1782835210; bh=KvEuzWN4/8GhThxsZZqLKe7NfOvgxySwuaYJL1oGxgM=; h=date:from:reply-to:to:message-id:in-reply-to:subject:mime-version:content-type:content-transfer-encoding; b= ----==_mimepart_6a43e80a534fa_19718184997aa Content-Type: text/plain; charset=utf-8 Content-Transfer-Encoding: quoted-printable ##- Please type your reply above this line -## Hello,</p> <p>Thank you for contacting Adobe=E2=80=99s Trust & Safety team. We will re= view your report and take action if we can confirm a misuse of an Adobe pro= duct or service (for malicious or illegal purposes) or an abuse on Adobe's = online hosted services according to <a href=3D"https://www.adobe.com/legal/= terms.html"> Adobe=E2=80=99s Terms of Use and Community Guidelines.</p> <p>Please note, we often receive reports for other types of issues that we = might not be able to address. For instructions on how to report some of the= most common issues we see, please follow the instructions below:</p> <ul> <li>Account: For help or questions about Adobe account information, how to= manage your subscriptions or report billing issues, how to reset your pass= word, or how to verify your email, please <a href=3D"https://helpx.adobe.co= m/contact.html">visit the Adobe Customer Care help centre</a>.</li> <li>Phishing: To report an email, website, or pop-up window that falsely c= laims to represent Adobe, please contact phishing@adobe.com</li> <li>Piracy: To report software piracy (copying, selling, or use of softwar= e that hasn&#39;t been properly licensed) please visit the <a href=3D"https= ://www.adobe.com/ca/genuine.html">Adobe anti-piracy page </a> and click "re= port it here" near the bottom of the page. </ul> =20 <p>Regards,<br>Adobe Trust & Safety</p> [26ELNK-KJ49R] ----==_mimepart_6a43e80a534fa_19718184997aa Content-Type: text/html; charset=utf-8 Content-Transfer-Encoding: quoted-printable <!DOCTYPE html><html><head> <meta http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dutf-8"> <style type=3D"text/css"> table td { border-collapse: collapse; } body[dir=3Drtl] .directional_text_wrapper { direction: rtl; unicode-bid= i: embed; } </style> </head> <body lang=3D"en-ca" style=3D"width: 100%!important; margin: 0; padding: 0;= "> <div style=3D"padding: 10px; line-height: 1.5; font-family: 'Lucida Grand= e',Verdana,Arial,sans-serif; font-size: 12px; color:#444444;"> <div style=3D"color: #b5b5b5;">##- Please type your reply above this li= ne -##</div> <p dir=3D"ltr">Hello,</p><p dir=3D"ltr"></p><p dir=3D"ltr">Thank you fo= r contacting Adobe=E2=80=99s Trust &amp; Safety team. We will review your r= eport and take action if we can confirm a misuse of an Adobe product or ser= vice (for malicious or illegal purposes) or an abuse on Adobe's online host= ed services according to <a href=3D"https://www.adobe.com/legal/terms.html"= > Adobe=E2=80=99s Terms of Use and Community Guidelines.</a></p><p dir=3D"= ltr"></p><p dir=3D"ltr">Please note, we often receive reports for other typ= es of issues that we might not be able to address. For instructions on how = to report some of the most common issues we see, please follow the instruct= ions below:</p> <ul><br><li>Account: For help or questions about Adobe acc= ount information, how to manage your subscriptions or report billing issues= , how to reset your password, or how to verify your email, please <a href= =3D"https://helpx.adobe.com/contact.html">visit the Adobe Customer Care hel= p centre</a>.</li><br><li>Phishing: To report an email, website, or pop-up= window that falsely claims to represent Adobe, please contact phishing@ado= be.com</li><br><li>Piracy: To report software piracy (copying, selling, or= use of software that hasn't been properly licensed) please visit the <a hr= ef=3D"https://www.adobe.com/ca/genuine.html">Adobe anti-piracy page </a> an= d click "report it here" near the bottom of the page.<br></li></ul> <br><p= dir=3D"ltr">Regards,<br>Adobe Trust &amp; Safety</p> </div> <div style=3D"padding: 10px; line-height: 1.5; font-family: 'Lucida Grand= e',Verdana,Arial,sans-serif; font-size: 12px; color: #aaaaaa; margin: 10px 0 14px 0; padding-top: 10px; border-top: 1px solid #eeeeee= ;"> &nbsp; =20 =20 &nbsp; <br> <br> Adobe, 345 Park Avenue, San Jose, CA 95110 USA.= <br> <br> For information on Adobe products and services visit <a href=3D"h= ttp://adobe.com/" alt=3D"Adobe.com" style=3D"color: #959595; font-size: 11p= x; font-family: 'adobe-clean', Helvetica, Arial, sans-serif;" target=3D"_bl= ank"><u>Adobe.com</u></a>.<br>=20 &nbsp; =20 </div> <span style=3D"color:#FFFFFF" aria-hidden=3D"true" class=3D"zd_encoded_id">= [26ELNK-KJ49R]</span> <div itemscope=3D"" itemtype=3D"http://schema.org/EmailMessage" style=3D"di= splay:none"> <div itemprop=3D"action" itemscope=3D"" itemtype=3D"http://sc= hema.org/ViewAction"> <link itemprop=3D"url" href=3D"https://adobesafety= .zendesk.com/hc/requests/947075"> <meta itemprop=3D"name" content=3D"Vie= w ticket"> </div></div></body></html> ----==_mimepart_6a43e80a534fa_19718184997aa-- Comments Comments settings Photo of Swen Werner Like Comment Share Add a comment… Open Emoji Keyboard No comments, yet. Be the first to comment. Start the conversation SWE1YHWH - OUROBOROS13 SWE1YHWH - OUROBOROS13 swenwerner@SWE1YHWH Philippe, Sundeep and 691 connections are subscribed 780 subscribers Subscribed Unsubscribe from {:entityName} Swen WernerStatus is online MessagingYou are on the messaging overlay. Press enter to open the list of conversations. Compose message You are on the messaging overlay. Press enter to open the list of conversations. My Digital Truth picture My Digital Truth

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""data:image/png;base64,..."""

# %%
""" /tmp/ipykernel_1672/4063539710.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
  df_csection = pd.read_csv('/content/thebigcsection237.csv', delim_whitespace=True, skiprows=1)
---------------------------------------------------------------------------
ParserError                               Traceback (most recent call last)
/tmp/ipykernel_1672/4063539710.py in <cell line: 0>()
      1 import pandas as pd
      2
----> 3 df_csection = pd.read_csv('/content/thebigcsection237.csv', delim_whitespace=True, skiprows=1)
      4 display(df_csection.head())
      5 print(df_csection.columns)

3 frames/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
   1024     kwds.update(kwds_defaults)
   1025
-> 1026     return _read(filepath_or_buffer, kwds)
   1027
   1028

/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
    624
    625     with parser:
--> 626         return parser.read(nrows)
    627
    628

/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
   1921                     columns,
   1922                     col_dict,
-> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
   1924                     nrows
   1925                 )

/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
    232         try:
    233             if self.low_memory:
--> 234                 chunks = self._reader.read_low_memory(nrows)
    235                 # destructive to chunks
    236                 data = _concatenate_chunks(chunks)

parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()

parsers.pyx in pandas._libs.parsers.TextReader._read_rows()

parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()

parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()

parsers.pyx in pandas._libs.parsers.raise_parser_error()

ParserError: Error tokenizing data. C error: Expected 8 fields in line 4, saw 12
"""

# %%
print(df_csection.columns)
party_counts = df_csection['Party'].value_counts()
display(party_counts)
